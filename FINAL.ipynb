# %% [markdown]
# # CP1-24-final
#
# ## How to run:
#
# The project is divided into 3 parts. Before beginning, the repository has been merged with https://github.com/ojha-aditya/CP1-24-midterm.git with all commit history. In the same folder as the midterm, now, exist:
#
# - code subfolder containing module named final.py with the importable functions outlined in the algorithm task.
# - data subfolder containing data files with the naming convention 'OA###_sinewalk.csv' and the corresponding markdown files containing the experiment metadata for GPS data of sinewalk.
# - documentation subfolder containing this Jupyter notebook FINAL.ipynb containing the plots of raw data, curve fit using non-linear fitting and corresponding fourier transforms and inverse fourier transform of the mean fft.
#
# ### Running the code:
#
# -

# %%
import sys
import os
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import final
import pandas as pd

# %%
pathname = 'ojha-aditya/data/'
csv_files = final.filename_lister(pathname,'sinewalk','csv')
md_files = final.filename_lister(pathname,'sinewalk','md')

# %%
for i in range(1):#len(csv_files)):
    csv, md = csv_files[i], md_files[i]
    data = final.get_coordinates(pathname+csv)
    data = data[0][2:],data[1][2:]
    data = final.shift_coordinates(data[0],data[1])
    n = int(np.ceil(np.log2(len(data[0]))))
    data_resamp = final.resample_data(data[0],data[1],n)
    

    temperature = int(final.fahrenheit_to_kelvin(final.read_temperature(pathname+md)))
    label = f'{temperature} K'
    color = list(mcolors.CSS4_COLORS.keys())[10:][i]
    plt.plot(data[0], data[1], marker='.', lw=0, color=color, label=label)
    plt.plot(data_resamp[0], data_resamp[1], marker='x', lw=0, color=color, label=label)
    plt.legend(bbox_to_anchor=(1.04, 0.5), loc="center left")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 7
#       5 data = final.shift_coordinates(data[0],data[1])
#       6 n = int(np.ceil(np.log2(len(data[0]))))
# ----> 7 data_resamp = final.resample_data(data[0],data[1],n)
#      10 temperature = int(final.fahrenheit_to_kelvin(final.read_temperature(pathname+md)))
#      11 label = f'{temperature} K'
#
# File /workspaces/CP1-24-final/final.py:187, in resample_data(x, y, n)
#     184 no_of_points = 2 ** n # number of points for fft
#     185 x_equidistant = np.linspace(x[0], x[-1], no_of_points) # interpolating x values to 2^n
# --> 187 y_equidistant = CubicSpline(x, y)(x_equidistant)#interp1d(x, y, kind='linear')(x_equidistant)
#     188 #np.interp(x_equidistant, x, y)
#     190 return np.array(x_equidistant), np.array(y_equidistant)
#
# File ~/.local/lib/python3.12/site-packages/scipy/interpolate/_cubic.py:751, in CubicSpline.__init__(self, x, y, axis, bc_type, extrapolate)
#     750 def __init__(self, x, y, axis=0, bc_type='not-a-knot', extrapolate=None):
# --> 751     x, dx, y, axis, _ = prepare_input(x, y, axis)
#     752     n = len(x)
#     754     bc, y = self._validate_bc(bc_type, y, y.shape[1:], axis)
#
# File ~/.local/lib/python3.12/site-packages/scipy/interpolate/_cubic.py:70, in prepare_input(x, y, axis, dydx)
#      68 dx = np.diff(x)
#      69 if np.any(dx <= 0):
# ---> 70     raise ValueError("`x` must be strictly increasing sequence.")
#      72 y = np.moveaxis(y, axis, 0)
#      73 if dydx is not None:
#
# ValueError: `x` must be strictly increasing sequence.

# %%
# Out:
# ['aliceblue',
#  'antiquewhite',
#  'aqua',
#  'aquamarine',
#  'azure',
#  'beige',
#  'bisque',
#  'black',
#  'blanchedalmond',
#  'blue',
#  'blueviolet',
#  'brown',
#  'burlywood',
#  'cadetblue',
#  'chartreuse',
#  'chocolate',
#  'coral',
#  'cornflowerblue',
#  'cornsilk',
#  'crimson',
#  'cyan',
#  'darkblue',
#  'darkcyan',
#  'darkgoldenrod',
#  'darkgray',
#  'darkgreen',
#  'darkgrey',
#  'darkkhaki',
#  'darkmagenta',
#  'darkolivegreen',
#  'darkorange',
#  'darkorchid',
#  'darkred',
#  'darksalmon',
#  'darkseagreen',
#  'darkslateblue',
#  'darkslategray',
#  'darkslategrey',
#  'darkturquoise',
#  'darkviolet',
#  'deeppink',
#  'deepskyblue',
#  'dimgray',
#  'dimgrey',
#  'dodgerblue',
#  'firebrick',
#  'floralwhite',
#  'forestgreen',
#  'fuchsia',
#  'gainsboro',
#  'ghostwhite',
#  'gold',
#  'goldenrod',
#  'gray',
#  'green',
#  'greenyellow',
#  'grey',
#  'honeydew',
#  'hotpink',
#  'indianred',
#  'indigo',
#  'ivory',
#  'khaki',
#  'lavender',
#  'lavenderblush',
#  'lawngreen',
#  'lemonchiffon',
#  'lightblue',
#  'lightcoral',
#  'lightcyan',
#  'lightgoldenrodyellow',
#  'lightgray',
#  'lightgreen',
#  'lightgrey',
#  'lightpink',
#  'lightsalmon',
#  'lightseagreen',
#  'lightskyblue',
#  'lightslategray',
#  'lightslategrey',
#  'lightsteelblue',
#  'lightyellow',
#  'lime',
#  'limegreen',
#  'linen',
#  'magenta',
#  'maroon',
#  'mediumaquamarine',
#  'mediumblue',
#  'mediumorchid',
#  'mediumpurple',
#  'mediumseagreen',
#  'mediumslateblue',
#  'mediumspringgreen',
#  'mediumturquoise',
#  'mediumvioletred',
#  'midnightblue',
#  'mintcream',
#  'mistyrose',
#  'moccasin',
#  'navajowhite',
#  'navy',
#  'oldlace',
#  'olive',
#  'olivedrab',
#  'orange',
#  'orangered',
#  'orchid',
#  'palegoldenrod',
#  'palegreen',
#  'paleturquoise',
#  'palevioletred',
#  'papayawhip',
#  'peachpuff',
#  'peru',
#  'pink',
#  'plum',
#  'powderblue',
#  'purple',
#  'rebeccapurple',
#  'red',
#  'rosybrown',
#  'royalblue',
#  'saddlebrown',
#  'salmon',
#  'sandybrown',
#  'seagreen',
#  'seashell',
#  'sienna',
#  'silver',
#  'skyblue',
#  'slateblue',
#  'slategray',
#  'slategrey',
#  'snow',
#  'springgreen',
#  'steelblue',
#  'tan',
#  'teal',
#  'thistle',
#  'tomato',
#  'turquoise',
#  'violet',
#  'wheat',
#  'white',
#  'whitesmoke',
#  'yellow',
#  'yellowgreen']
