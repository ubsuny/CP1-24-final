# %%
import matplotlib.pyplot as plt
import distance_calc as dc
import direction_of_motion as md


lats,lons=dc.reader("/workspaces/CP1-24-final/abruns123/data/sin_data/experiment_2_data.csv")
distances=[]
xy_coords=[]
x_pos=[0]
y_pos=[0]
for i in range(1,len(lats)-1):
    distances.append(dc.diffm(lats[i], lats[i+1], lons[i], lons[i+1]))

for i in range(len(distances)):
    xy_coords.append(dc.get_coords(distances, distances[i], i))
    x,y=xy_coords[i]
    x_pos.append(x)
    y_pos.append(y)
plt.figure()
plt.plot(x_pos,y_pos)
plt.ylabel("Y (m)")
plt.xlabel("X (m)")
plt.title("GPS Position Map")
plt.grid()
plt.show()
plt.figure()
acc,times=md.acc_reader("/abruns123/data/down_data/Raw Data.csv")
directions=md.get_direction(times, acc)
plt.plot(times,directions)
plt.title("Elevator Direction of Motion")
plt.ylabel("Z direction")
plt.xlabel("time (s)")
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 27
#      25 plt.show()
#      26 plt.figure()
# ---> 27 acc,times=md.acc_reader("/abruns123/data/down_data/Raw Data.csv")
#      28 directions=md.get_direction(times, acc)
#      29 plt.plot(times,directions)
#
# File /workspaces/CP1-24-final/abruns123/code/direction_of_motion.py:131, in acc_reader(path)
#     126 def acc_reader(path):
#     127     """
#     128     acc_reader reads a file to isolate
#     129     linear acceleration z data and time data
#     130     """
# --> 131     file =pd.read_csv(path)
#     133     #condition1 and 2 are used to verify that
#     134     #a file with the correct data is input
#     135     condition2=False
#
# ...
